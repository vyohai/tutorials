# %% [markdown]
# # Drone equations
# based on:
# https://engineeringmedia.com/videos
# "Drone Simulation and Control" section
#
# https://towardsdatascience.com/demystifying-drone-dynamics-ee98b1ba882f
#
# https://andrew.gibiansky.com/blog/physics/quadcopter-dynamics/
#
# https://moorepants.github.io/eme134/lab-05.html

# %% [markdown]
# ## relevant equations
#
# **quaternion to rotation matrix**:
# http://www.songho.ca/opengl/gl_quaternion.html
#
# **rotation matrix to quaternin**:
# ![download.jpg](attachment:download.jpg)
#
# **euler angles from rotation matrix**
# http://eecs.qmul.ac.uk/~gslabaugh/publications/euler.pdf
#
# **quaternion update**:
# https://lucidar.me/en/quaternions/quaternion-and-gyroscope/
#
# **quaternion multiplication**:
# https://lucidar.me/en/quaternions/quaternion-product/
#
#
# **moments and angular acceleration**:
# https://andrew.gibiansky.com/blog/physics/quadcopter-dynamics/
